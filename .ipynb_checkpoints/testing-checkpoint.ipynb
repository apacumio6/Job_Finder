# %%
import datetime
import numpy as np
import pandas as pd
import csv

# %%
jobs_df = pd.read_csv('jobList.csv', header=None, skip_blank_lines=True, names=['company', 'company_location', 'job_title'])
jobs_df = jobs_df[['company', 'company_location', 'job_title']]
# Out:
#                                                                                                                                                                                                                                                                      company  \
# NaN  address                                            company                                            company_location                         job_link                                           job_title                                                         lat
# 0.0  1200 Park Pl, San Mateo, CA 94403, USA             Edmodo                                             San Mateo, CA                            http://indeed.com//rc/clk?jk=277656606c986d9a&f... Data Analyst                                               37.5460527
# ...

# %%
for row in jobs_df.iterrows():
    print(row)
